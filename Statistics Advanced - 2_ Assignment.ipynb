# %% [markdown]
# #Statistics Advanced - 2| Assignment

# %% [markdown]
# 1. What is hypothesis testing in statistics?
# - **Hypothesis testing** is a statistical method used to make decisions about a population based on sample data. It involves formulating two hypotheses — the **null hypothesis (H₀)**, which assumes no effect or no difference, and the **alternative hypothesis (H₁)**, which suggests there is an effect or difference. Based on the sample data and a chosen significance level (α), statistical tests are applied to decide whether to reject H₀ or not.
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
# - The null hypothesis (H₀) is an assumption that there is no effect, no relationship, or no difference in the population. It represents the default position to be tested.
# - The alternative hypothesis (H₁) is the opposite of the null hypothesis, suggesting that there is an effect, a relationship, or a difference.
# - The main difference is that the null assumes no change, while the alternative proposes that a change or difference exists.
# 3. Explain the significance level in hypothesis testing and its role in deciding the outcome of a test.
# - The significance level, denoted by α, is the probability of rejecting the null hypothesis when it is actually true. It represents the tolerance for making a Type I error. Common values are 0.05 or 0.01. In hypothesis testing, the significance level is compared with the p-value. If the p-value is less than or equal to α, the null hypothesis is rejected; otherwise, it is not rejected. Thus, the significance level acts as a threshold for deciding the outcome of a test.
# 4. What are Type I and Type II errors? Give examples of each.
# - Type I error occurs when the null hypothesis is true but is wrongly rejected. It is also called a false positive.
# - **Example:** A medical test indicates a patient has a disease when they actually do not.
# - Type II error occurs when the null hypothesis is false but is wrongly accepted (failing to reject it). It is also called a false negative.
# - **Example:** A medical test fails to detect a disease when the patient actually has it.
# 5. What is the difference between a Z-test and a T-test? Explain when to use each.
# - A Z-test is used when the population variance is known and the sample size is large (usually n > 30). It assumes data follows a normal distribution.
# - A T-test is used when the population variance is unknown and the sample size is small (n ≤ 30). It uses the sample standard deviation to estimate variability.
# - In short, use a Z-test for large samples with known variance, and a T-test for small samples with unknown variance.
# 6. Question 6: Write a Python program to generate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10   # number of trials
p = 0.5  # probability of success
size = 1000  # number of random samples

# Generate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=range(0, n+2), edgecolor='black', align='left')
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 7. Question 7: Implement hypothesis testing using Z-statistics for a sample dataset in Python. Show the Python code and interpret the results.
# - sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
# 50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
# 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
# 50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# %%
import numpy as np
from scipy import stats

# Sample data
sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# Hypothesized population mean
mu0 = 50

# Calculate sample mean and std deviation
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)
n = len(sample_data)

# Z-statistic
z_stat = (sample_mean - mu0) / (sample_std / np.sqrt(n))

# p-value (two-tailed)
p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

print("Sample Mean:", sample_mean)
print("Sample Std Dev:", sample_std)
print("Z-statistic:", z_stat)
print("p-value:", p_value)
# Out:
# Sample Mean: 50.08888888888889
# Sample Std Dev: 0.5365379910807955
# Z-statistic: 0.9940271559503017
# p-value: 0.3202096468890012

# %% [markdown]
# 8. Question 8: Write a Python script to simulate data from a normal distribution and calculate the 95% confidence interval for its mean. Plot the data using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Simulate normal distribution data
np.random.seed(42)
data = np.random.normal(loc=50, scale=5, size=100)  # mean=50, std=5, n=100

# Sample statistics
mean = np.mean(data)
std_err = stats.sem(data)  # standard error of the mean

# 95% confidence interval
confidence = 0.95
ci = stats.t.interval(confidence, len(data)-1, loc=mean, scale=std_err)

# Plot histogram of data
plt.hist(data, bins=15, edgecolor='black', alpha=0.7)
plt.axvline(ci[0], color='red', linestyle='dashed', linewidth=2, label=f'95% CI Lower = {ci[0]:.2f}')
plt.axvline(ci[1], color='green', linestyle='dashed', linewidth=2, label=f'95% CI Upper = {ci[1]:.2f}')
plt.axvline(mean, color='blue', linewidth=2, label=f'Mean = {mean:.2f}')
plt.title("Normal Distribution Data with 95% Confidence Interval")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# 9. Question 9: Write a Python function to calculate the Z-scores from a dataset and visualize the standardized data using a histogram. Explain what the Z-scores represent in terms of standard deviations from the mean.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate Z-scores
def calculate_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    return z_scores

# Generate sample dataset
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=200)  # mean=100, std=15

# Calculate Z-scores
z_scores = calculate_z_scores(data)

# Plot histogram of standardized data
plt.hist(z_scores, bins=15, edgecolor='black', alpha=0.7)
plt.title("Histogram of Z-scores (Standardized Data)")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# Display first 10 Z-scores
print("First 10 Z-scores:", z_scores[:10])
# Out:
# First 10 Z-scores: [ 0.57876651 -0.10498128  0.74133645  1.68390811 -0.20823509 -0.20821741
#   1.74440619  0.87027971 -0.46162987  0.62813359]
